# %% [markdown]
# # GHCN Analysis

# %%
import os
from glob import glob
from copy import copy 

import dask
import dask.bag as db
import dask.dataframe as dd

import pandas as pd

from distributed import Client
from dask_jobqueue import SLURMCluster

from IPython.display import display
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

from dask import config as cfg

cfg.set({'distributed.scheduler.worker-ttl': None})

# %%
# Set LOCAL to True for single-machine execution while developing
# Set LOCAL to False for cluster execution
LOCAL = True

if LOCAL:
    # This line creates a single-machine dask client
    client = Client()
else:    
    # This line creates a SLURM cluster dask and dask client
    # Logging outputs will be stored in /scratch/{your-netid}
    
    cluster = SLURMCluster(
       # Memory and core limits should be sufficient here
       memory='32GB', cores=16,

       # Ensure that Dask uses the correct version of Python on the cluster
       python='/scratch/work/public/dask/{}/bin/python'.format(dask.__version__),                           

       # Place the output logs in an accessible location
       job_extra=['--export=NONE --output=/scratch/{}/slurm-%j.out'.format(os.environ['SLURM_JOB_USER'])]
    )

    cluster.submit_command = 'slurm'
    cluster.scale(50)

    display(cluster)
    client = Client(cluster)

display(client)
# Out:
# <Client: 'tcp://127.0.0.1:45135' processes=4 threads=8, memory=4.00 GiB>

# %%
# !ls -lh /scratch/work/courses/DSGA1004-2021/listenbrainz/
# Out:
# total 15G
# -rw-r--r--. 1 2502497 users 1.9G Apr 11 22:40 interactions_test.parquet
# -rw-r--r--. 1 2502497 users 6.8G Apr 11 22:41 interactions_train.parquet
# -rw-r--r--. 1 2502497 users 1.9G Apr 11 22:41 interactions_train_small.parquet
# -rw-r--r--. 1 2502497 users 767M Apr 11 22:41 tracks_test.parquet
# -rw-r--r--. 1 2502497 users 2.1G Apr 11 22:41 tracks_train.parquet
# -rw-r--r--. 1 2502497 users 1.5G Apr 11 22:41 tracks_train_small.parquet
# -rw-r--r--. 1 2502497 users 128K Apr 11 22:41 users_test.parquet
# -rw-r--r--. 1 2502497 users 141K Apr 11 22:41 users_train.parquet
# -rw-r--r--. 1 2502497 users 124K Apr 11 22:41 users_train_small.parquet

# %%
train_small = dd.read_parquet("/scratch/work/courses/DSGA1004-2021/listenbrainz/tracks_train_small.parquet",
                              engine='pyarrow')

# %%
train_small.tail()
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 725.11 MiB -- Worker memory limit: 1.00 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 848.09 MiB -- Worker memory limit: 1.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 848.09 MiB -- Worker memory limit: 1.00 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 820.30 MiB -- Worker memory limit: 1.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 820.30 MiB -- Worker memory limit: 1.00 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Input In [42], in <module>
# ----> 1 train_small.tail()
#
# File /ext3/miniconda3/lib/python3.9/site-packages/dask/dataframe/core.py:1130, in _Frame.tail(self, n, compute)
#    1127 result = new_dd_object(graph, name, self._meta, self.divisions[-2:])
#    1129 if compute:
# -> 1130     result = result.compute()
#    1131 return result
#
# File /ext3/miniconda3/lib/python3.9/site-packages/dask/base.py:288, in DaskMethodsMixin.compute(self, **kwargs)
#     264 def compute(self, **kwargs):
#     265     """Compute this dask collection
#     266
#     267     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     286     dask.base.compute
#     287     """
# --> 288     (result,) = compute(self, traverse=False, **kwargs)
#     289     return result
#
# File /ext3/miniconda3/lib/python3.9/site-packages/dask/base.py:570, in compute(*args, **kwargs)
#     567     keys.append(x.__dask_keys__())
#     568     postcomputes.append(x.__dask_postcompute__())
# --> 570 results = schedule(dsk, keys, **kwargs)
#     571 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/client.py:2693, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2691         should_rejoin = False
#    2692 try:
# -> 2693     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2694 finally:
#    2695     for f in futures.values():
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/client.py:1969, in Client.gather(self, futures, errors, direct, asynchronous)
#    1967 else:
#    1968     local_worker = None
# -> 1969 return self.sync(
#    1970     self._gather,
#    1971     futures,
#    1972     errors=errors,
#    1973     direct=direct,
#    1974     local_worker=local_worker,
#    1975     asynchronous=asynchronous,
#    1976 )
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/client.py:865, in Client.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     863     return future
#     864 else:
# --> 865     return sync(
#     866         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     867     )
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/utils.py:327, in sync(loop, func, callback_timeout, *args, **kwargs)
#     325 if error[0]:
#     326     typ, exc, tb = error[0]
# --> 327     raise exc.with_traceback(tb)
#     328 else:
#     329     return result[0]
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/utils.py:310, in sync.<locals>.f()
#     308     if callback_timeout is not None:
#     309         future = asyncio.wait_for(future, callback_timeout)
# --> 310     result[0] = yield future
#     311 except Exception:
#     312     error[0] = sys.exc_info()
#
# File /ext3/miniconda3/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     759 exc_info = None
#     761 try:
# --> 762     value = future.result()
#     763 except Exception:
#     764     exc_info = sys.exc_info()
#
# File /ext3/miniconda3/lib/python3.9/site-packages/distributed/client.py:1834, in Client._gather(self, futures, errors, direct, local_worker)
#    1832         exc = CancelledError(key)
#    1833     else:
# -> 1834         raise exception.with_traceback(traceback)
#    1835     raise exc
#    1836 if errors == "skip":
#
# KilledWorker: ("('read-parquet-0e6bde09597561b65850ed2fbe0b1358', 0)", <WorkerState 'tcp://127.0.0.1:39275', name: 0, status: closed, memory: 0, processing: 1>)

# %%
def calculate_max_difference(
    files: list, 
    initial_partitions: int = int(1e6),
    num_workers: int = None, 
) -> None:
            
    def filter_values(x):
        return (x['element'] in ['TMAX', 'TMIN'] 
                and x['value'] != -9999 
                and x['quality'] == ' ')
        
        
    def set_default(x):
        """Cleans each entry to work better with foldby
        """
        x = copy(x)

        x['TMAX'] = x['value']
        x['TMIN'] = x['value']
        x['id'] =  "_".join(
            [x['station_id'], str(x['year']), str(x['month']), str(x['day'])]
        )
        
        return {k: x[k] for k in ('TMAX', 'TMIN', 'id')}
        

    def combine_entries(x, y):
        x = copy(x)

        tmax = max(x['TMAX'], y['TMAX'])
        tmin = min(x['TMIN'], y['TMIN'])

        x['TMAX'] = tmax 
        x['TMIN'] = tmin

        return x
    
    def get_biggest_diff(x, y):
        diffx = x['TMAX'] - x['TMIN']
        diffy = y['TMAX'] - y['TMIN']

        if diffx > diffy:
            return x
        else:
            return y
        
    def get_station(x):
        x['station_id'] = x['id'].split("_")[0]
        del x['id']
        return x 

            
    # Operate on subset of the files at any given time 
    dfs = []
    
    
    bag = (db.from_sequence(files, npartitions=initial_partitions).map(load_daily)
            .flatten()
            .filter(filter_values)
            .map(set_default)  
            .foldby(lambda x: x['id'], combine_entries, combine=combine_entries)
            .map(lambda x: x[1])
            .map(get_station))

    bag = pd.DataFrame(bag.compute(scheduler='processes', num_workers=num_workers))

    if len(bag) == 0:
        return pd.DataFrame()

    bag['t_range'] = bag['TMAX'] - bag['TMIN']
    bag = bag.groupby('station_id').max().reset_index()
    bag = bag[['station_id', 't_range']]
    
    if len(bag):
        return bag
    return pd.DataFrame()

# %% [markdown]
# # Tiny Data Results

# %%
# %%time 
files = sorted(glob('/scratch/work/courses/DSGA1004-2021/ghcnd_tiny/*.dly'))
sm_df = calculate_max_difference(files)
sm_df.to_parquet('tdiff-tiny.parquet')
sm_df
# Out:
# CPU times: user 472 ms, sys: 302 ms, total: 774 ms
# Wall time: 2.02 s
#     station_id  t_range
# 0  ASN00063226      274
# 1  CA002402688      272
# 2  CA004012040      339
# 3  MXN00018074      222
# 4  MXN00026133      311
# 5  MXN00031086      350
# 6  RMC00914399      122
# 7  USC00046773      317
# 8  USC00180565      239
# 9  USC00295691      372

# %% [markdown]
# # Small Data Results

# %%
# %%time 
start = 0
files = sorted(glob('/scratch/work/courses/DSGA1004-2021/ghcnd_small/*.dly'))
meta_chunk = 200
iters = len(files) // meta_chunk + 1
tmp_dir = './tmp_small'

for i in range(start, iters):
    print("meta chunk", i)
    df = calculate_max_difference(files[i * meta_chunk: (i + 1) * meta_chunk])
    
    if not os.path.isdir(tmp_dir):
        os.mkdir(tmp_dir)
    df.to_csv(f'{tmp_dir}/data_{i}.csv')
    
small_df = pd.concat(
    [pd.read_csv(f'{tmp_dir}/{f}') for f in os.listdir(tmp_dir) if f.endswith('csv')], 
    ignore_index=True
)

# Handle duplicates
small_df = small_df.groupby('station_id').max().reset_index()
small_df = small_df[['station_id', 't_range']]
small_df.to_parquet('tdiff-small.parquet')
small_df
# Out:
# meta chunk 0
# meta chunk 1
# meta chunk 2
# meta chunk 3
# meta chunk 4
# meta chunk 5
# CPU times: user 18.7 s, sys: 5.64 s, total: 24.4 s
# Wall time: 1min 3s
#       station_id  t_range
# 0    AGM00060490    272.0
# 1    AJ000037639    233.0
# 2    AM000037686    285.0
# 3    ARM00087909    277.0
# 4    ASN00005094    180.0
# ..           ...      ...
# 343  USW00053167    279.0
# 344  USW00053169    218.0
# 345  USW00064776    278.0
# 346  USW00094724    299.0
# 347  VMM00048808    245.0
#
# [348 rows x 2 columns]

# %% [markdown]
# # All Data Results

# %%
# %%time 
start = 477
files = sorted(glob('/scratch/work/courses/DSGA1004-2021/ghcnd_all/*.dly'))
meta_chunk = 100
iters = len(files) // meta_chunk + 1
tmp_dir = './tmp_all'

for i in range(start, iters):
    print("meta chunk", i)
    df = calculate_max_difference(files[i * meta_chunk: (i + 1) * meta_chunk])
    
    if not os.path.isdir(tmp_dir):
        os.mkdir(tmp_dir)
    df.to_csv(f'{tmp_dir}/data_{i}.csv')
    
all_df = pd.concat(
    [pd.read_csv(f'{tmp_dir}/{f}') for f in os.listdir(tmp_dir) if f.endswith('csv')], 
    ignore_index=True
)
all_df = all_df.groupby('station_id').max().reset_index()
all_df = all_df[['station_id', 't_range']]
all_df.to_parquet('tdiff-all.parquet')
all_df
# Out:
# meta chunk 477
# meta chunk 478
# meta chunk 479
# meta chunk 480
# meta chunk 481
# meta chunk 482
# meta chunk 483
# meta chunk 484
# meta chunk 485
# meta chunk 486
# meta chunk 487
# meta chunk 488
# meta chunk 489
# meta chunk 490
# meta chunk 491
# meta chunk 492
# meta chunk 493
# meta chunk 494
# meta chunk 495
# meta chunk 496
# meta chunk 497
# meta chunk 498
# meta chunk 499
# meta chunk 500
# meta chunk 501
# meta chunk 502
# meta chunk 503
# meta chunk 504
# meta chunk 505
# meta chunk 506
# meta chunk 507
# meta chunk 508
# meta chunk 509
# meta chunk 510
# meta chunk 511
# meta chunk 512
# meta chunk 513
# meta chunk 514
# meta chunk 515
# meta chunk 516
# meta chunk 517
# meta chunk 518
# meta chunk 519
# meta chunk 520
# meta chunk 521
# meta chunk 522
# meta chunk 523
# meta chunk 524
# meta chunk 525
# meta chunk 526
# meta chunk 527
# meta chunk 528
# meta chunk 529
# meta chunk 530
# meta chunk 531
# meta chunk 532
# meta chunk 533
# meta chunk 534
# meta chunk 535
# meta chunk 536
# meta chunk 537
# meta chunk 538
# meta chunk 539
# meta chunk 540
# meta chunk 541
# meta chunk 542
# meta chunk 543
# meta chunk 544
# meta chunk 545
# meta chunk 546
# meta chunk 547
# meta chunk 548
# meta chunk 549
# meta chunk 550
# meta chunk 551
# meta chunk 552
# meta chunk 553
# meta chunk 554
# meta chunk 555
# meta chunk 556
# meta chunk 557
# meta chunk 558
# meta chunk 559
# meta chunk 560
# meta chunk 561
# meta chunk 562
# meta chunk 563
# meta chunk 564
# meta chunk 565
# meta chunk 566
# meta chunk 567
# meta chunk 568
# meta chunk 569
# meta chunk 570
# meta chunk 571
# meta chunk 572
# meta chunk 573
# meta chunk 574
# meta chunk 575
# meta chunk 576
# meta chunk 577
# meta chunk 578
# meta chunk 579
# meta chunk 580
# meta chunk 581
# meta chunk 582
# meta chunk 583
# meta chunk 584
# meta chunk 585
# meta chunk 586
# meta chunk 587
# meta chunk 588
# meta chunk 589
# meta chunk 590
# meta chunk 591
# meta chunk 592
# meta chunk 593
# meta chunk 594
# meta chunk 595
# meta chunk 596
# meta chunk 597
# meta chunk 598
# meta chunk 599
# meta chunk 600
# meta chunk 601
# meta chunk 602
# meta chunk 603
# meta chunk 604
# meta chunk 605
# meta chunk 606
# meta chunk 607
# meta chunk 608
# meta chunk 609
# meta chunk 610
# meta chunk 611
# meta chunk 612
# meta chunk 613
# meta chunk 614
# meta chunk 615
# meta chunk 616
# meta chunk 617
# meta chunk 618
# meta chunk 619
# meta chunk 620
# meta chunk 621
# meta chunk 622
# meta chunk 623
# meta chunk 624
# meta chunk 625
# meta chunk 626
# meta chunk 627
# meta chunk 628
# meta chunk 629
# meta chunk 630
# meta chunk 631
# meta chunk 632
# meta chunk 633
# meta chunk 634
# meta chunk 635
# meta chunk 636
# meta chunk 637
# meta chunk 638
# meta chunk 639
# meta chunk 640
# meta chunk 641
# meta chunk 642
# meta chunk 643
# meta chunk 644
# meta chunk 645
# meta chunk 646
# meta chunk 647
# meta chunk 648
# meta chunk 649
# meta chunk 650
# meta chunk 651
# meta chunk 652
# meta chunk 653
# meta chunk 654
# meta chunk 655
# meta chunk 656
# meta chunk 657
# meta chunk 658
# meta chunk 659
# meta chunk 660
# meta chunk 661
# meta chunk 662
# meta chunk 663
# meta chunk 664
# meta chunk 665
# meta chunk 666
# meta chunk 667
# meta chunk 668
# meta chunk 669
# meta chunk 670
# meta chunk 671
# meta chunk 672
# meta chunk 673
# meta chunk 674
# meta chunk 675
# meta chunk 676
# meta chunk 677
# meta chunk 678
# meta chunk 679
# meta chunk 680
# meta chunk 681
# meta chunk 682
# meta chunk 683
# meta chunk 684
# meta chunk 685
# meta chunk 686
# meta chunk 687
# meta chunk 688
# meta chunk 689
# meta chunk 690
# meta chunk 691
# meta chunk 692
# meta chunk 693
# meta chunk 694
# meta chunk 695
# meta chunk 696
# meta chunk 697
# meta chunk 698
# meta chunk 699
# meta chunk 700
# meta chunk 701
# meta chunk 702
# meta chunk 703
# meta chunk 704
# meta chunk 705
# meta chunk 706
# meta chunk 707
# meta chunk 708
# meta chunk 709
# meta chunk 710
# meta chunk 711
# meta chunk 712
# meta chunk 713
# meta chunk 714
# meta chunk 715
# meta chunk 716
# meta chunk 717
# meta chunk 718
# meta chunk 719
# meta chunk 720
# meta chunk 721
# meta chunk 722
# meta chunk 723
# meta chunk 724
# meta chunk 725
# meta chunk 726
# meta chunk 727
# meta chunk 728
# meta chunk 729
# meta chunk 730
# meta chunk 731
# meta chunk 732
# meta chunk 733
# meta chunk 734
# meta chunk 735
# meta chunk 736
# meta chunk 737
# meta chunk 738
# meta chunk 739
# meta chunk 740
# meta chunk 741
# meta chunk 742
# meta chunk 743
# meta chunk 744
# meta chunk 745
# meta chunk 746
# meta chunk 747
# meta chunk 748
# meta chunk 749
# meta chunk 750
# meta chunk 751
# meta chunk 752
# meta chunk 753
# meta chunk 754
# meta chunk 755
# meta chunk 756
# meta chunk 757
# meta chunk 758
# meta chunk 759
# meta chunk 760
# meta chunk 761
# meta chunk 762
# meta chunk 763
# meta chunk 764
# meta chunk 765
# meta chunk 766
# meta chunk 767
# meta chunk 768
# meta chunk 769
# meta chunk 770
# meta chunk 771
# meta chunk 772
# meta chunk 773
# meta chunk 774
# meta chunk 775
# meta chunk 776
# meta chunk 777
# meta chunk 778
# meta chunk 779
# meta chunk 780
# meta chunk 781
# meta chunk 782
# meta chunk 783
# meta chunk 784
# meta chunk 785
# meta chunk 786
# meta chunk 787
# meta chunk 788
# meta chunk 789
# meta chunk 790
# meta chunk 791
# meta chunk 792
# meta chunk 793
# meta chunk 794
# meta chunk 795
# meta chunk 796
# meta chunk 797
# meta chunk 798
# meta chunk 799
# meta chunk 800
# meta chunk 801
# meta chunk 802
# meta chunk 803
# meta chunk 804
# meta chunk 805
# meta chunk 806
# meta chunk 807
# meta chunk 808
# meta chunk 809
# meta chunk 810
# meta chunk 811
# meta chunk 812
# meta chunk 813
# meta chunk 814
# meta chunk 815
# meta chunk 816
# meta chunk 817
# meta chunk 818
# meta chunk 819
# meta chunk 820
# meta chunk 821
# meta chunk 822
# meta chunk 823
# meta chunk 824
# meta chunk 825
# meta chunk 826
# meta chunk 827
# meta chunk 828
# meta chunk 829
# meta chunk 830
# meta chunk 831
# meta chunk 832
# meta chunk 833
# meta chunk 834
# meta chunk 835
# meta chunk 836
# meta chunk 837
# meta chunk 838
# meta chunk 839
# meta chunk 840
# meta chunk 841
# meta chunk 842
# meta chunk 843
# meta chunk 844
# meta chunk 845
# meta chunk 846
# meta chunk 847
# meta chunk 848
# meta chunk 849
# meta chunk 850
# meta chunk 851
# meta chunk 852
# meta chunk 853
# meta chunk 854
# meta chunk 855
# meta chunk 856
# meta chunk 857
# meta chunk 858
# meta chunk 859
# meta chunk 860
# meta chunk 861
# meta chunk 862
# meta chunk 863
# meta chunk 864
# meta chunk 865
# meta chunk 866
# meta chunk 867
# meta chunk 868
# meta chunk 869
# meta chunk 870
# meta chunk 871
# meta chunk 872
# meta chunk 873
# meta chunk 874
# meta chunk 875
# meta chunk 876
# meta chunk 877
# meta chunk 878
# meta chunk 879
# meta chunk 880
# meta chunk 881
# meta chunk 882
# meta chunk 883
# meta chunk 884
# meta chunk 885
# meta chunk 886
# meta chunk 887
# meta chunk 888
# meta chunk 889
# meta chunk 890
# meta chunk 891
# meta chunk 892
# meta chunk 893
# meta chunk 894
# meta chunk 895
# meta chunk 896
# meta chunk 897
# meta chunk 898
# meta chunk 899
# meta chunk 900
# meta chunk 901
# meta chunk 902
# meta chunk 903
# meta chunk 904
# meta chunk 905
# meta chunk 906
# meta chunk 907
# meta chunk 908
# meta chunk 909
# meta chunk 910
# meta chunk 911
# meta chunk 912
# meta chunk 913
# meta chunk 914
# meta chunk 915
# meta chunk 916
# meta chunk 917
# meta chunk 918
# meta chunk 919
# meta chunk 920
# meta chunk 921
# meta chunk 922
# meta chunk 923
# meta chunk 924
# meta chunk 925
# meta chunk 926
# meta chunk 927
# meta chunk 928
# meta chunk 929
# meta chunk 930
# meta chunk 931
# meta chunk 932
# meta chunk 933
# meta chunk 934
# meta chunk 935
# meta chunk 936
# meta chunk 937
# meta chunk 938
# meta chunk 939
# meta chunk 940
# meta chunk 941
# meta chunk 942
# meta chunk 943
# meta chunk 944
# meta chunk 945
# meta chunk 946
# meta chunk 947
# meta chunk 948
# meta chunk 949
# meta chunk 950
# meta chunk 951
# meta chunk 952
# meta chunk 953
# meta chunk 954
# meta chunk 955
# meta chunk 956
# meta chunk 957
# meta chunk 958
# meta chunk 959
# meta chunk 960
# meta chunk 961
# meta chunk 962
# meta chunk 963
# meta chunk 964
# meta chunk 965
# meta chunk 966
# meta chunk 967
# meta chunk 968
# meta chunk 969
# meta chunk 970
# meta chunk 971
# meta chunk 972
# meta chunk 973
# meta chunk 974
# meta chunk 975
# meta chunk 976
# meta chunk 977
# meta chunk 978
# meta chunk 979
# meta chunk 980
# meta chunk 981
# meta chunk 982
# meta chunk 983
# meta chunk 984
# meta chunk 985
# meta chunk 986
# meta chunk 987
# meta chunk 988
# meta chunk 989
# meta chunk 990
# meta chunk 991
# meta chunk 992
# meta chunk 993
# meta chunk 994
# meta chunk 995
# meta chunk 996
# meta chunk 997
# meta chunk 998
# meta chunk 999
# meta chunk 1000
# meta chunk 1001
# meta chunk 1002
# meta chunk 1003
# meta chunk 1004
# meta chunk 1005
# meta chunk 1006
# meta chunk 1007
# meta chunk 1008
# meta chunk 1009
# meta chunk 1010
# meta chunk 1011
# meta chunk 1012
# meta chunk 1013
# meta chunk 1014
# meta chunk 1015
# meta chunk 1016
# meta chunk 1017
# meta chunk 1018
# meta chunk 1019
# meta chunk 1020
# meta chunk 1021
# meta chunk 1022
# meta chunk 1023
# meta chunk 1024
# meta chunk 1025
# meta chunk 1026
# meta chunk 1027
# meta chunk 1028
# meta chunk 1029
# meta chunk 1030
# meta chunk 1031
# meta chunk 1032
# meta chunk 1033
# meta chunk 1034
# meta chunk 1035
# meta chunk 1036
# meta chunk 1037
# meta chunk 1038
# meta chunk 1039
# meta chunk 1040
# meta chunk 1041
# meta chunk 1042
# meta chunk 1043
# meta chunk 1044
# meta chunk 1045
# meta chunk 1046
# meta chunk 1047
# meta chunk 1048
# meta chunk 1049
# meta chunk 1050
# meta chunk 1051
# meta chunk 1052
# meta chunk 1053
# meta chunk 1054
# meta chunk 1055
# meta chunk 1056
# meta chunk 1057
# meta chunk 1058
# meta chunk 1059
# meta chunk 1060
# meta chunk 1061
# meta chunk 1062
# meta chunk 1063
# meta chunk 1064
# meta chunk 1065
# meta chunk 1066
# meta chunk 1067
# meta chunk 1068
# meta chunk 1069
# meta chunk 1070
# meta chunk 1071
# meta chunk 1072
# meta chunk 1073
# meta chunk 1074
# meta chunk 1075
# meta chunk 1076
# meta chunk 1077
# meta chunk 1078
# meta chunk 1079
# meta chunk 1080
# meta chunk 1081
# meta chunk 1082
# meta chunk 1083
# meta chunk 1084
# meta chunk 1085
# meta chunk 1086
# meta chunk 1087
# meta chunk 1088
# meta chunk 1089
# meta chunk 1090
# meta chunk 1091
# meta chunk 1092
# meta chunk 1093
# meta chunk 1094
# meta chunk 1095
# meta chunk 1096
# meta chunk 1097
# meta chunk 1098
# meta chunk 1099
# meta chunk 1100
# meta chunk 1101
# meta chunk 1102
# meta chunk 1103
# meta chunk 1104
# meta chunk 1105
# meta chunk 1106
# meta chunk 1107
# meta chunk 1108
# meta chunk 1109
# meta chunk 1110
# meta chunk 1111
# meta chunk 1112
# meta chunk 1113
# meta chunk 1114
# meta chunk 1115
# meta chunk 1116
# meta chunk 1117
# meta chunk 1118
# meta chunk 1119
# meta chunk 1120
# meta chunk 1121
# meta chunk 1122
# meta chunk 1123
# meta chunk 1124
# meta chunk 1125
# meta chunk 1126
# meta chunk 1127
# meta chunk 1128
# meta chunk 1129
# meta chunk 1130
# meta chunk 1131
# meta chunk 1132
# meta chunk 1133
# meta chunk 1134
# meta chunk 1135
# meta chunk 1136
# meta chunk 1137
# meta chunk 1138
# meta chunk 1139
# meta chunk 1140
# meta chunk 1141
# meta chunk 1142
# meta chunk 1143
# meta chunk 1144
# meta chunk 1145
# meta chunk 1146
# meta chunk 1147
# meta chunk 1148
# meta chunk 1149
# meta chunk 1150
# meta chunk 1151
# meta chunk 1152
# meta chunk 1153
# meta chunk 1154
# meta chunk 1155
# meta chunk 1156
# meta chunk 1157
# meta chunk 1158
# meta chunk 1159
# meta chunk 1160
# meta chunk 1161
# meta chunk 1162
# meta chunk 1163
# meta chunk 1164
# meta chunk 1165
# meta chunk 1166
# meta chunk 1167
# meta chunk 1168
# meta chunk 1169
# meta chunk 1170
# meta chunk 1171
# meta chunk 1172
# meta chunk 1173
# meta chunk 1174
# meta chunk 1175
# meta chunk 1176
# meta chunk 1177
# meta chunk 1178
# meta chunk 1179
# meta chunk 1180
# meta chunk 1181
# meta chunk 1182
# meta chunk 1183
# meta chunk 1184
# CPU times: user 24min 50s, sys: 6min 12s, total: 31min 3s
# Wall time: 1h 25min 42s
#         station_id  t_range
# 0      ACW00011604    106.0
# 1      ACW00011647     33.0
# 2      AE000041196    257.0
# 3      AEM00041194    244.0
# 4      AEM00041217    277.0
# ...            ...      ...
# 40288  ZI000067969    299.0
# 40289  ZI000067975    294.0
# 40290  ZI000067977    279.0
# 40291  ZI000067983    254.0
# 40292  ZI000067991    289.0
#
# [40293 rows x 2 columns]
