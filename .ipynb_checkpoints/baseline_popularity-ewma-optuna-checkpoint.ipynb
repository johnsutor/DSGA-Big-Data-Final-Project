# %%
import numpy as np
import optuna 
import os

from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    max, avg, sum, count, countDistinct,
    percentile_approx, col, asc, desc, collect_list,
    lit, rand, when, exp, datediff, lit
)
from pyspark.ml.evaluation import RankingEvaluator
from dateutil.parser import parse
spark = SparkSession.builder.master('spark://cm003:10397').getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/13 18:25:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
def gen_utiltiy_matrix(interactions, tracks, span=np.inf):
    """
    Idea is to replace sum(num_listens) w/ sum(exp(days_from_train_end / span) * listen_on_a_given_day)
    We're summing anyway so we don't have to worry about normalization constants. (i.e., the further back
    you go, the less of a "listen" a given listen is)
    
    This weighted sum is also consistent with all the other pre-processing from here, so just plug and chug
    Obviously we're not ewma'ing the val or test sets when generating the utility matrix, since these are what
    we're trying to predict
    """

    interactions.createOrReplaceTempView('interactions')
    tracks.createOrReplaceTempView('tracks')

    if span == np.inf:
        listens_per_user_track = spark.sql(
            """
            SELECT user_id,universal_id,sum(num_listens) as num_listens
            FROM interactions
            LEFT JOIN tracks
            ON tracks.recording_msid=interactions.recording_msid
            GROUP BY user_id,universal_id
            """
        )

    else:
        listens_per_user_track = spark.sql(
            """
            SELECT user_id,universal_id,CAST(timestamp AS DATE) as date,sum(num_listens) as num_listens
            FROM interactions
            LEFT JOIN tracks
            ON tracks.recording_msid=interactions.recording_msid
            GROUP BY user_id,universal_id,date
            """
        )

        listens_per_user_track = listens_per_user_track.withColumn(
            'exp_days_from_train_end',
            exp(datediff(col('date'), lit(parse('2017-12-31'))) / span)
        )

        listens_per_user_track = listens_per_user_track.withColumn(
            'weighted_num_listens',
            listens_per_user_track.num_listens * listens_per_user_track.exp_days_from_train_end
        )
    
        listens_per_user_track = listens_per_user_track.groupBy(
            'universal_id', 'user_id'
        ).agg(
            sum(listens_per_user_track.weighted_num_listens).alias('num_listens')
        )

    listens_per_user = listens_per_user_track.select(
        listens_per_user_track.user_id, listens_per_user_track.num_listens
    ).groupBy('user_id').agg(
        sum(listens_per_user_track.num_listens).alias('total_listens')
    )

    listens_per_user = listens_per_user.withColumn(
        'use_for_fit',
        when(
            listens_per_user.total_listens >= 500, True
        ).otherwise(
            False
        )
    )

    normed_listens_per_user_track = listens_per_user_track.join(listens_per_user, how='left', on='user_id')
    normed_listens_per_user_track = normed_listens_per_user_track.withColumn(
        "prop_listens",
        col("num_listens")/col("total_listens")
    ).select(
        ['user_id', 'universal_id', 'prop_listens', 'use_for_fit']
    ).orderBy(
        col('user_id').asc(),
        col('prop_listens').desc()
    )

    return normed_listens_per_user_track


def calc_baseline_popularity(utility_mat, beta):
    utility_mat = utility_mat.filter(
        utility_mat.use_for_fit
    )

    baseline_popularity = utility_mat.groupBy(
        'universal_id'
    ).agg(
        sum(utility_mat.prop_listens).alias("total"),
        count(utility_mat.prop_listens).alias("num_users"),
    )

    baseline_popularity = baseline_popularity.filter(
        baseline_popularity.num_users >= 250
    )
    
    baseline_popularity = baseline_popularity.withColumn(
        "P_i",
        col("total") / (col("num_users") + beta)
    ).orderBy(
        "P_i",
        ascending=False
    )

    return baseline_popularity.select(['universal_id','P_i'])

def calc_performance_metrics(predicted, actual):
    actual_compressed = actual.groupBy(
        'user_id'
    ).agg(
        collect_list(col('universal_id').astype('double')).alias('universal_id'),
        collect_list(col('prop_listens').astype('double')).alias('prop_listens')
    )
    actual_compressed = actual_compressed.withColumn('key', lit(1))


    predicted_compressed = predicted.limit(5000).agg(
        collect_list(col('universal_id').astype('double')).alias('predicted_universal_id')
    ).withColumn('key', lit(1))

    results = actual_compressed.join(
        predicted_compressed,
        how='left',
        on='key'
    )

    return RankingEvaluator(
        predictionCol='predicted_universal_id',
        labelCol='universal_id',
        metricName='meanAveragePrecisionAtK',
        k=100
    ).evaluate(results)

# %%
interactions_train = spark.read.parquet('interactions_split_train.parquet')
interactions_val = spark.read.parquet('interactions_split_val.parquet')
interactions_test = spark.read.parquet("/scratch/work/courses/DSGA1004-2021/listenbrainz/interactions_test.parquet")

tracks_train = spark.read.parquet('tracks_train.parquet')
tracks_test = spark.read.parquet('tracks_test.parquet')

# %%
# utility_mat_train = gen_utiltiy_matrix(interactions_train, tracks_train, span=365*6)
# utility_mat_val = gen_utiltiy_matrix(interactions_val, tracks_train)
# utility_mat_test = gen_utiltiy_matrix(interactions_test, tracks_test)

# %%
# candidate_betas = [50000]

# betas = []
# map_at_100_train = []
# map_at_100_val = []
# map_at_100_test = []

# for beta in candidate_betas:
#     print(f"Running Beta = {round(beta, 0)}")

#     baseline_pops_train = calc_baseline_popularity(utility_mat_train, beta)
    
#     metrics_train = calc_performance_metrics(baseline_pops_train, utility_mat_train)
#     metrics_val = calc_performance_metrics(baseline_pops_train, utility_mat_val)
#     metrics_test = calc_performance_metrics(baseline_pops_train, utility_mat_test)

#     betas.append(beta)
#     map_at_100_train.append(metrics_train)
#     map_at_100_val.append(metrics_val)
#     map_at_100_test.append(metrics_test)
    
#     print(f"MAP Train: {round(metrics_train, 5)}, MAP Val: {round(metrics_val, 5)}, MAP Test: {round(metrics_test, 5)}")

# %%
# Handle different parameters 
SEED = 69
TRIALS = 1500

def objective(trial):
    beta = trial.suggest_float('beta', 1e-7, 1e7, log=True)
    span = trial.suggest_int('span', 1, 365 * 10, log=True)
    
    utility_mat_train = gen_utiltiy_matrix(interactions_train, tracks_train, span=span)
    utility_mat_val = gen_utiltiy_matrix(interactions_val, tracks_train, span=span)
    
    baseline_pops_train = calc_baseline_popularity(utility_mat_train, beta)
    
    map_val = calc_performance_metrics(baseline_pops_train, utility_mat_val)
    
    return map_val
    
study = optuna.create_study(
    study_name='extension_search',
    direction='maximize', 
    sampler=optuna.samplers.TPESampler(seed=SEED), 
    storage='sqlite:///optuna_extension.db', 
    load_if_exists=True
)
study.optimize(objective, n_trials=TRIALS)
# Out:
# [I 2023-05-13 18:25:11,071] Using an existing study with name 'extension_search' instead of creating a new one.
# [I 2023-05-13 18:26:18,086] Trial 7 finished with value: 0.011107591000305533 and parameters: {'beta': 0.0014043917300979281, 'span': 668}. Best is trial 5 with value: 0.017736540378198076.
# [I 2023-05-13 18:27:15,481] Trial 8 finished with value: 0.01112238070935478 and parameters: {'beta': 0.0080082081553874, 'span': 561}. Best is trial 5 with value: 0.017736540378198076.
# [I 2023-05-13 18:28:01,692] Trial 9 finished with value: 0.0 and parameters: {'beta': 7.225795408760466, 'span': 5}. Best is trial 5 with value: 0.017736540378198076.
# [I 2023-05-13 18:28:49,853] Trial 10 finished with value: 0.0 and parameters: {'beta': 2.9490298710538617e-06, 'span': 1}. Best is trial 5 with value: 0.017736540378198076.
# [I 2023-05-13 18:29:36,780] Trial 11 finished with value: 0.01689975334645203 and parameters: {'beta': 7049585.36578529, 'span': 93}. Best is trial 5 with value: 0.017736540378198076.
# [I 2023-05-13 18:30:23,398] Trial 12 finished with value: 0.01854551008051354 and parameters: {'beta': 2935520.024713795, 'span': 2792}. Best is trial 12 with value: 0.01854551008051354.
# [I 2023-05-13 18:31:14,281] Trial 13 finished with value: 0.018533627031020513 and parameters: {'beta': 498496.0529963026, 'span': 3331}. Best is trial 12 with value: 0.01854551008051354.
# [I 2023-05-13 18:31:56,943] Trial 14 finished with value: 0.018537297666792577 and parameters: {'beta': 2468699.3245083825, 'span': 3148}. Best is trial 12 with value: 0.01854551008051354.
# [I 2023-05-13 18:32:43,947] Trial 15 finished with value: 0.018567426716803333 and parameters: {'beta': 112563.71442308997, 'span': 2253}. Best is trial 15 with value: 0.018567426716803333.
# [I 2023-05-13 18:33:24,170] Trial 16 finished with value: 0.01853744967642211 and parameters: {'beta': 60974.16972382561, 'span': 2591}. Best is trial 15 with value: 0.018567426716803333.
# [I 2023-05-13 18:34:08,655] Trial 17 finished with value: 0.01657070654021201 and parameters: {'beta': 35019.245317553694, 'span': 89}. Best is trial 15 with value: 0.018567426716803333.
# [I 2023-05-13 18:35:02,503] Trial 18 finished with value: 0.01855305916229408 and parameters: {'beta': 17009.458066448693, 'span': 1940}. Best is trial 15 with value: 0.018567426716803333.
# [I 2023-05-13 18:35:44,261] Trial 19 finished with value: 0.017962116309830616 and parameters: {'beta': 2198.3234957835975, 'span': 1340}. Best is trial 15 with value: 0.018567426716803333.
# [I 2023-05-13 18:36:28,734] Trial 20 finished with value: 0.01878651863524764 and parameters: {'beta': 45850.96020264996, 'span': 205}. Best is trial 20 with value: 0.01878651863524764.
# [I 2023-05-13 18:37:21,255] Trial 21 finished with value: 0.014442537341043058 and parameters: {'beta': 420.51765444324536, 'span': 189}. Best is trial 20 with value: 0.01878651863524764.
# [I 2023-05-13 18:38:03,018] Trial 22 finished with value: 0.019102048955194864 and parameters: {'beta': 46511.86184057179, 'span': 1803}. Best is trial 22 with value: 0.019102048955194864.
# [I 2023-05-13 18:38:57,889] Trial 23 finished with value: 0.01932063329632602 and parameters: {'beta': 171385.5727118079, 'span': 1039}. Best is trial 23 with value: 0.01932063329632602.
# [I 2023-05-13 18:39:44,319] Trial 24 finished with value: 0.019443207436633126 and parameters: {'beta': 438895.4880803059, 'span': 944}. Best is trial 24 with value: 0.019443207436633126.
# [I 2023-05-13 18:40:37,375] Trial 25 finished with value: 0.0193990562617974 and parameters: {'beta': 363105.9900731513, 'span': 1078}. Best is trial 24 with value: 0.019443207436633126.
# [I 2023-05-13 18:41:21,544] Trial 26 finished with value: 0.019416445720338262 and parameters: {'beta': 9302572.648806386, 'span': 1058}. Best is trial 24 with value: 0.019443207436633126.
# [I 2023-05-13 18:42:16,416] Trial 27 finished with value: 0.019210898684445685 and parameters: {'beta': 7748307.860160041, 'span': 1367}. Best is trial 24 with value: 0.019443207436633126.
# [I 2023-05-13 18:43:10,198] Trial 28 finished with value: 0.019462958677682485 and parameters: {'beta': 1090568.9591928038, 'span': 320}. Best is trial 28 with value: 0.019462958677682485.
# [I 2023-05-13 18:43:49,123] Trial 29 finished with value: 0.019244136480525486 and parameters: {'beta': 505037.2874731059, 'span': 309}. Best is trial 28 with value: 0.019462958677682485.
# [I 2023-05-13 18:44:33,779] Trial 30 finished with value: 0.019869690183465405 and parameters: {'beta': 1666688.2327438658, 'span': 386}. Best is trial 30 with value: 0.019869690183465405.
# [I 2023-05-13 18:45:25,185] Trial 31 finished with value: 0.01889810224871839 and parameters: {'beta': 7357.273417244204, 'span': 350}. Best is trial 30 with value: 0.019869690183465405.
# [I 2023-05-13 18:46:16,221] Trial 32 finished with value: 0.019646429658376253 and parameters: {'beta': 1193910.3822118798, 'span': 829}. Best is trial 30 with value: 0.019869690183465405.
# [I 2023-05-13 18:46:58,034] Trial 33 finished with value: 0.019930175922192244 and parameters: {'beta': 978949.0329285053, 'span': 428}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:47:56,433] Trial 34 finished with value: 0.019924760491262135 and parameters: {'beta': 1127291.69725947, 'span': 426}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:48:49,375] Trial 35 finished with value: 0.017579408915959584 and parameters: {'beta': 6713.617457244226, 'span': 141}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:49:43,432] Trial 36 finished with value: 0.019876690608982478 and parameters: {'beta': 1910256.7877125475, 'span': 453}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:50:35,063] Trial 37 finished with value: 0.014287513061989505 and parameters: {'beta': 318.6132508570771, 'span': 40}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:51:24,362] Trial 38 finished with value: 0.01984558364216292 and parameters: {'beta': 9724443.403209476, 'span': 436}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:52:07,407] Trial 39 finished with value: 0.011646164170052634 and parameters: {'beta': 40.7012711268405, 'span': 525}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:53:00,308] Trial 40 finished with value: 0.019750942723183857 and parameters: {'beta': 241995.63483404208, 'span': 527}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:53:53,431] Trial 41 finished with value: 0.017680527547941437 and parameters: {'beta': 3072.736716924095, 'span': 245}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:54:39,125] Trial 42 finished with value: 0.01989180596861553 and parameters: {'beta': 1769510.3554554037, 'span': 442}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:55:27,341] Trial 43 finished with value: 0.019833636641963873 and parameters: {'beta': 1649338.719651453, 'span': 411}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:56:19,338] Trial 44 finished with value: 0.019627220982841146 and parameters: {'beta': 130229.69036271743, 'span': 786}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:57:03,925] Trial 45 finished with value: 0.01970227452490716 and parameters: {'beta': 1570955.9123151945, 'span': 637}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:57:49,788] Trial 46 finished with value: 0.0181443343009635 and parameters: {'beta': 25077.953891348126, 'span': 148}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:58:29,853] Trial 47 finished with value: 0.0192811079480376 and parameters: {'beta': 3058024.668902269, 'span': 313}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 18:59:21,407] Trial 48 finished with value: 0.011188851269151475 and parameters: {'beta': 0.21735709144706084, 'span': 733}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:00:14,360] Trial 49 finished with value: 0.019820585644729338 and parameters: {'beta': 122761.51893921578, 'span': 416}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:01:04,006] Trial 50 finished with value: 0.017628239907826145 and parameters: {'beta': 639746.0072591413, 'span': 114}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:01:48,670] Trial 51 finished with value: 0.016003842928819234 and parameters: {'beta': 10704.689842737896, 'span': 62}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:02:36,970] Trial 52 finished with value: 0.019785673230570188 and parameters: {'beta': 7370408.944737603, 'span': 494}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:03:17,859] Trial 53 finished with value: 0.019027386058132603 and parameters: {'beta': 2866232.1430391707, 'span': 242}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:04:07,497] Trial 54 finished with value: 0.01990455618649711 and parameters: {'beta': 8035412.582289534, 'span': 443}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:05:02,324] Trial 55 finished with value: 0.018816826786306726 and parameters: {'beta': 237796.75612470382, 'span': 203}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:05:50,585] Trial 56 finished with value: 0.019266944026656664 and parameters: {'beta': 2446869.237076534, 'span': 294}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:06:31,885] Trial 57 finished with value: 0.01967293184733206 and parameters: {'beta': 42128.87910019046, 'span': 551}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:07:25,282] Trial 58 finished with value: 0.019203025939894383 and parameters: {'beta': 620020.6830818161, 'span': 1404}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:08:19,420] Trial 59 finished with value: 0.018578191312636026 and parameters: {'beta': 95802.93780838093, 'span': 2146}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:09:11,544] Trial 60 finished with value: 0.0195941044846546 and parameters: {'beta': 3652869.2644615024, 'span': 693}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:10:00,015] Trial 61 finished with value: 0.01886484174513186 and parameters: {'beta': 1085044.976184113, 'span': 205}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:10:44,614] Trial 62 finished with value: 0.019837401084307538 and parameters: {'beta': 8809964.575969439, 'span': 411}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:11:32,360] Trial 63 finished with value: 0.019888288383954258 and parameters: {'beta': 442558.9428769313, 'span': 444}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:12:24,222] Trial 64 finished with value: 0.019589662785744102 and parameters: {'beta': 288357.347392283, 'span': 697}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:13:17,496] Trial 65 finished with value: 0.019405018379188434 and parameters: {'beta': 682377.8910309176, 'span': 1082}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:14:08,209] Trial 66 finished with value: 0.01976263090860582 and parameters: {'beta': 69712.03399473039, 'span': 403}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:15:01,742] Trial 67 finished with value: 0.019046163266233034 and parameters: {'beta': 24816.063388874416, 'span': 289}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:15:49,449] Trial 68 finished with value: 0.019178298369983457 and parameters: {'beta': 1768953.3598030612, 'span': 1599}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:16:29,936] Trial 69 finished with value: 0.019635629541613832 and parameters: {'beta': 3342306.5239237593, 'span': 863}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:17:24,373] Trial 70 finished with value: 0.018370724797246375 and parameters: {'beta': 204617.23686162624, 'span': 152}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:18:05,340] Trial 71 finished with value: 0.019102533667135234 and parameters: {'beta': 519343.8811623662, 'span': 248}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:18:48,928] Trial 72 finished with value: 0.019851484550044173 and parameters: {'beta': 8517404.814733844, 'span': 476}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:19:34,416] Trial 73 finished with value: 0.019717657313564577 and parameters: {'beta': 3667404.561988237, 'span': 539}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:20:14,281] Trial 74 finished with value: 0.01971608576829926 and parameters: {'beta': 1088373.9647640402, 'span': 618}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:21:09,796] Trial 75 finished with value: 0.019736522857687653 and parameters: {'beta': 9202046.380200477, 'span': 361}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:21:53,681] Trial 76 finished with value: 0.019383978223650115 and parameters: {'beta': 295666.4330530321, 'span': 1004}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:22:33,491] Trial 77 finished with value: 0.019759408695380776 and parameters: {'beta': 80811.81842296252, 'span': 442}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:23:26,418] Trial 78 finished with value: 0.019342960026696023 and parameters: {'beta': 3905362.271412415, 'span': 1171}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:24:19,554] Trial 79 finished with value: 0.019627540679311276 and parameters: {'beta': 1006234.3835230253, 'span': 866}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:25:16,586] Trial 80 finished with value: 0.019233326135402275 and parameters: {'beta': 15808.168235296667, 'span': 345}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:26:10,396] Trial 81 finished with value: 0.01973394846669125 and parameters: {'beta': 1451325.3985591184, 'span': 552}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:26:59,198] Trial 82 finished with value: 0.019828302245308797 and parameters: {'beta': 8140067.970798136, 'span': 406}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:27:54,503] Trial 83 finished with value: 0.019856376807040197 and parameters: {'beta': 5001841.509446221, 'span': 470}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:28:41,481] Trial 84 finished with value: 0.019599345037518128 and parameters: {'beta': 3645355.4140897957, 'span': 726}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:29:20,447] Trial 85 finished with value: 0.01906732015425021 and parameters: {'beta': 508426.8373561849, 'span': 254}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:30:05,312] Trial 86 finished with value: 0.01978219905227945 and parameters: {'beta': 1993284.7213018357, 'span': 499}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:30:53,202] Trial 87 finished with value: 0.019272737724525094 and parameters: {'beta': 148387.01068733603, 'span': 319}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:31:34,783] Trial 88 finished with value: 0.01970149235605687 and parameters: {'beta': 5088635.82827841, 'span': 638}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:32:25,469] Trial 89 finished with value: 0.018357799285744283 and parameters: {'beta': 347638.1639240842, 'span': 172}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:33:19,334] Trial 90 finished with value: 0.019722194284761383 and parameters: {'beta': 874620.6928527793, 'span': 850}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:34:10,580] Trial 91 finished with value: 0.019862695261747696 and parameters: {'beta': 1934253.3836314066, 'span': 480}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:34:59,443] Trial 92 finished with value: 0.01986278520553783 and parameters: {'beta': 2106249.9951442312, 'span': 478}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:35:39,799] Trial 93 finished with value: 0.019581998612978633 and parameters: {'beta': 1793686.4187712944, 'span': 346}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:36:33,562] Trial 94 finished with value: 0.019691690306145353 and parameters: {'beta': 169892.19908835276, 'span': 639}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:37:24,214] Trial 95 finished with value: 0.019253410483655864 and parameters: {'beta': 619620.0526443636, 'span': 1255}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:38:18,111] Trial 96 finished with value: 0.01876947277233458 and parameters: {'beta': 48344.553426697275, 'span': 219}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:38:56,387] Trial 97 finished with value: 0.019209384510607785 and parameters: {'beta': 4481608.694949726, 'span': 286}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:39:48,347] Trial 98 finished with value: 0.019891805968615534 and parameters: {'beta': 1628725.0138889747, 'span': 442}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:40:37,281] Trial 99 finished with value: 0.018545147558662777 and parameters: {'beta': 1825574.8285304527, 'span': 181}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:41:25,251] Trial 100 finished with value: 0.019755749703722836 and parameters: {'beta': 301280.412143093, 'span': 371}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:42:16,089] Trial 101 finished with value: 0.01912607864227209 and parameters: {'beta': 85330.65722944189, 'span': 264}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:42:59,906] Trial 102 finished with value: 0.0198682237633453 and parameters: {'beta': 812652.2819828306, 'span': 472}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:43:46,195] Trial 103 finished with value: 0.019714066138786044 and parameters: {'beta': 696025.6194594152, 'span': 573}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:44:35,145] Trial 104 finished with value: 0.019867081857736328 and parameters: {'beta': 1065208.9035594931, 'span': 448}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:45:28,858] Trial 105 finished with value: 0.019647142437857527 and parameters: {'beta': 1018573.4241649896, 'span': 746}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:46:18,474] Trial 106 finished with value: 0.019755123479376087 and parameters: {'beta': 406844.7914662494, 'span': 370}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:47:10,161] Trial 107 finished with value: 0.019182615347461154 and parameters: {'beta': 158315.47718220067, 'span': 296}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:47:57,134] Trial 108 finished with value: 0.0194503601499051 and parameters: {'beta': 4972802.278990871, 'span': 949}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:48:40,094] Trial 109 finished with value: 0.01896664330876371 and parameters: {'beta': 2199287.678172759, 'span': 225}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:49:21,356] Trial 110 finished with value: 0.01971617744376578 and parameters: {'beta': 1043341.0106261577, 'span': 575}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:50:13,754] Trial 111 finished with value: 0.01991094457557378 and parameters: {'beta': 266293.23089080094, 'span': 432}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:51:06,197] Trial 112 finished with value: 0.019867211560726666 and parameters: {'beta': 270722.8253631389, 'span': 457}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:52:00,530] Trial 113 finished with value: 0.019728432104473365 and parameters: {'beta': 245214.4597578242, 'span': 353}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:52:54,440] Trial 114 finished with value: 0.019615994158991228 and parameters: {'beta': 125901.44397161683, 'span': 768}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:53:39,220] Trial 115 finished with value: 0.019805415872083395 and parameters: {'beta': 64809.96643647101, 'span': 426}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:54:20,183] Trial 116 finished with value: 0.019198552344885357 and parameters: {'beta': 429648.15011551604, 'span': 279}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:55:13,320] Trial 117 finished with value: 0.019640793440932027 and parameters: {'beta': 27581.94074568507, 'span': 610}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:56:07,236] Trial 118 finished with value: 0.01979731524730676 and parameters: {'beta': 798891.9734557468, 'span': 399}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:56:50,290] Trial 119 finished with value: 0.018908880170017107 and parameters: {'beta': 227948.32355772398, 'span': 231}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:57:36,819] Trial 120 finished with value: 0.019599064304814957 and parameters: {'beta': 3480640.938615705, 'span': 683}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:58:18,093] Trial 121 finished with value: 0.01947126290127404 and parameters: {'beta': 9412628.448870622, 'span': 323}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:58:59,951] Trial 122 finished with value: 0.019786511439075657 and parameters: {'beta': 1429563.8544703943, 'span': 495}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 19:59:47,374] Trial 123 finished with value: 0.01989180596861553 and parameters: {'beta': 2297624.6514295135, 'span': 442}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:00:36,416] Trial 124 finished with value: 0.01992204778360454 and parameters: {'beta': 474894.8064835817, 'span': 425}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:01:26,300] Trial 125 finished with value: 0.0197431269015175 and parameters: {'beta': 356127.30466545984, 'span': 537}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:02:19,590] Trial 126 finished with value: 0.0198721012808484 and parameters: {'beta': 566370.7854462006, 'span': 376}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:02:55,574] Trial 127 finished with value: 0.019417621723445026 and parameters: {'beta': 3152019.8165087258, 'span': 933}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:03:39,734] Trial 128 finished with value: 0.019466474753040575 and parameters: {'beta': 492564.9664406766, 'span': 321}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:04:22,493] Trial 129 finished with value: 0.019144216584753303 and parameters: {'beta': 124278.4774427746, 'span': 269}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:05:13,837] Trial 130 finished with value: 0.01979416254849892 and parameters: {'beta': 4866852.054897774, 'span': 396}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:06:03,375] Trial 131 finished with value: 0.01878651863524764 and parameters: {'beta': 45746.58902532527, 'span': 205}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:06:47,270] Trial 132 finished with value: 0.019716815027085843 and parameters: {'beta': 982936.9568666507, 'span': 614}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:07:33,360] Trial 133 finished with value: 0.019821104180250657 and parameters: {'beta': 607283.9990370375, 'span': 420}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:08:17,217] Trial 134 finished with value: 0.01976166648636976 and parameters: {'beta': 2361914.1178292846, 'span': 515}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:08:55,033] Trial 135 finished with value: 0.019624023952617493 and parameters: {'beta': 281010.4782033364, 'span': 761}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:09:39,071] Trial 136 finished with value: 0.01878952536162729 and parameters: {'beta': 5260.865454445829, 'span': 353}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:10:17,316] Trial 137 finished with value: 0.01990059071137872 and parameters: {'beta': 1533020.138907705, 'span': 445}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:11:09,577] Trial 138 finished with value: 0.01969429239914208 and parameters: {'beta': 4677405.762985393, 'span': 645}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:11:59,195] Trial 139 finished with value: 0.019156809154017716 and parameters: {'beta': 1860422.474852917, 'span': 269}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:12:43,283] Trial 140 finished with value: 0.01946796651681577 and parameters: {'beta': 744734.1649415803, 'span': 321}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:13:37,426] Trial 141 finished with value: 0.019716786107392848 and parameters: {'beta': 6806469.591678615, 'span': 558}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:14:25,471] Trial 142 finished with value: 0.01984092228212117 and parameters: {'beta': 1417131.4913715348, 'span': 435}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:15:15,161] Trial 143 finished with value: 0.0198714261362899 and parameters: {'beta': 358847.1580284962, 'span': 378}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:15:58,271] Trial 144 finished with value: 0.01975192727820382 and parameters: {'beta': 108332.96786803496, 'span': 376}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:16:49,365] Trial 145 finished with value: 0.018361814130019683 and parameters: {'beta': 2641049.3251953265, 'span': 172}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:17:32,367] Trial 146 finished with value: 0.019633390337693034 and parameters: {'beta': 547339.458191281, 'span': 802}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:18:22,358] Trial 147 finished with value: 0.019787576448879712 and parameters: {'beta': 9719023.393854156, 'span': 498}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:19:13,590] Trial 148 finished with value: 0.019251371627740797 and parameters: {'beta': 1343751.992307351, 'span': 311}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:19:59,263] Trial 149 finished with value: 0.0190229683834078 and parameters: {'beta': 199683.18385415795, 'span': 240}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:20:52,269] Trial 150 finished with value: 0.019403942886308347 and parameters: {'beta': 13839.93010773, 'span': 379}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:21:32,105] Trial 151 finished with value: 0.019401135154061642 and parameters: {'beta': 484672.7191328169, 'span': 1079}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:22:23,480] Trial 152 finished with value: 0.01983755519310946 and parameters: {'beta': 77455.68741634444, 'span': 461}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:22:59,756] Trial 153 finished with value: 0.019704816179229097 and parameters: {'beta': 219767.16929166866, 'span': 579}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:23:42,961] Trial 154 finished with value: 0.017805624274736285 and parameters: {'beta': 1762.1184240704977, 'span': 443}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:24:28,132] Trial 155 finished with value: 0.019582062776237422 and parameters: {'beta': 873204.2884984142, 'span': 348}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:25:20,300] Trial 156 finished with value: 0.01961833630877778 and parameters: {'beta': 2884545.1425014823, 'span': 673}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:26:02,903] Trial 157 finished with value: 0.01974780810085297 and parameters: {'beta': 361624.8399647984, 'span': 523}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:26:44,198] Trial 158 finished with value: 0.019213034852108967 and parameters: {'beta': 1404739.49308723, 'span': 303}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:27:28,218] Trial 159 finished with value: 0.011804480436681242 and parameters: {'beta': 33.53438554011795, 'span': 438}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:28:13,060] Trial 160 finished with value: 0.01914286200581468 and parameters: {'beta': 4018917.1272113225, 'span': 250}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:28:58,598] Trial 161 finished with value: 0.019594458343218327 and parameters: {'beta': 839695.958243312, 'span': 700}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:29:50,511] Trial 162 finished with value: 0.019846319986050364 and parameters: {'beta': 1254486.897877703, 'span': 437}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:30:41,425] Trial 163 finished with value: 0.019870489315126628 and parameters: {'beta': 365320.1650029144, 'span': 375}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:31:29,253] Trial 164 finished with value: 0.019753613159277313 and parameters: {'beta': 153878.3300276442, 'span': 374}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:32:17,158] Trial 165 finished with value: 0.019711431424540505 and parameters: {'beta': 385997.4826374244, 'span': 568}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:33:09,598] Trial 166 finished with value: 0.01854411819957349 and parameters: {'beta': 2006929.6368096988, 'span': 2913}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:33:52,310] Trial 167 finished with value: 0.019025321598764595 and parameters: {'beta': 34454.365384924145, 'span': 294}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:34:31,605] Trial 168 finished with value: 0.019761119533446638 and parameters: {'beta': 209046.54411617893, 'span': 502}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:35:15,777] Trial 169 finished with value: 0.01972526057824456 and parameters: {'beta': 674026.670298895, 'span': 364}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:36:05,192] Trial 170 finished with value: 0.019565596195811503 and parameters: {'beta': 5773030.839534508, 'span': 870}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:36:45,470] Trial 171 finished with value: 0.01883525692165204 and parameters: {'beta': 397552.28700448613, 'span': 197}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:37:31,246] Trial 172 finished with value: 0.01989856160723477 and parameters: {'beta': 1025007.105917051, 'span': 446}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:38:14,151] Trial 173 finished with value: 0.019827958684996563 and parameters: {'beta': 1559898.8833745616, 'span': 407}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:38:56,958] Trial 174 finished with value: 0.019751666126330412 and parameters: {'beta': 3233554.369750916, 'span': 610}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:39:46,232] Trial 175 finished with value: 0.01984968028518356 and parameters: {'beta': 857128.508847017, 'span': 474}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:40:36,220] Trial 176 finished with value: 0.019418383026777414 and parameters: {'beta': 74216.38035354255, 'span': 333}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:41:27,325] Trial 177 finished with value: 0.0114683876624873 and parameters: {'beta': 1.2512794687034894, 'span': 285}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:42:08,473] Trial 178 finished with value: 0.01974870274452333 and parameters: {'beta': 269856.3358921114, 'span': 522}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:42:51,083] Trial 179 finished with value: 0.019875075882323238 and parameters: {'beta': 2494539.6362934276, 'span': 380}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:43:37,390] Trial 180 finished with value: 0.019872667608032697 and parameters: {'beta': 2583637.106388547, 'span': 391}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:44:26,097] Trial 181 finished with value: 0.018961536894828476 and parameters: {'beta': 2549574.2369258557, 'span': 223}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:45:02,348] Trial 182 finished with value: 0.019864518104694577 and parameters: {'beta': 5338710.949025823, 'span': 383}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:45:51,162] Trial 183 finished with value: 0.019586501905387032 and parameters: {'beta': 2154030.340686097, 'span': 339}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:46:31,741] Trial 184 finished with value: 0.01977840855524959 and parameters: {'beta': 977715.6395089757, 'span': 403}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:47:25,713] Trial 185 finished with value: 0.019716256905608298 and parameters: {'beta': 569946.7584327296, 'span': 614}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:48:20,404] Trial 186 finished with value: 0.01914823537500036 and parameters: {'beta': 4993881.990549919, 'span': 260}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:49:12,037] Trial 187 finished with value: 0.019826779453594123 and parameters: {'beta': 1857607.8042952567, 'span': 490}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:49:52,982] Trial 188 finished with value: 0.01792055969640807 and parameters: {'beta': 9638974.77860425, 'span': 129}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:50:40,171] Trial 189 finished with value: 0.01957137139001877 and parameters: {'beta': 1169330.672680758, 'span': 329}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:51:24,284] Trial 190 finished with value: 0.019837401084307545 and parameters: {'beta': 3700990.615525136, 'span': 411}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:52:14,582] Trial 191 finished with value: 0.019612797899878846 and parameters: {'beta': 567900.9297800269, 'span': 671}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:53:07,540] Trial 192 finished with value: 0.019866563700247822 and parameters: {'beta': 326673.5738677135, 'span': 450}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:53:53,447] Trial 193 finished with value: 0.019729069169337768 and parameters: {'beta': 1276227.8325905243, 'span': 544}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:54:30,374] Trial 194 finished with value: 0.019857661710767072 and parameters: {'beta': 178538.48777258932, 'span': 461}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:55:20,213] Trial 195 finished with value: 0.019876681101348017 and parameters: {'beta': 671869.109091084, 'span': 23}. Best is trial 33 with value: 0.019930175922192244.
# [I 2023-05-13 20:55:56,904] Trial 196 finished with value: 0.026004473809688185 and parameters: {'beta': 2263054.7266868562, 'span': 13}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 20:56:38,047] Trial 197 finished with value: 0.02189969177656308 and parameters: {'beta': 3369273.6817045696, 'span': 21}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 20:57:22,726] Trial 198 finished with value: 0.022034432709040444 and parameters: {'beta': 2567614.130108845, 'span': 20}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 20:58:10,508] Trial 199 finished with value: 0.021899691776563063 and parameters: {'beta': 2916473.8829234387, 'span': 21}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 20:58:58,382] Trial 200 finished with value: 0.0202857567300934 and parameters: {'beta': 3435923.2374502383, 'span': 22}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 20:59:47,910] Trial 201 finished with value: 0.019671943505966568 and parameters: {'beta': 5611520.575594031, 'span': 24}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:00:27,558] Trial 202 finished with value: 0.02341071978165186 and parameters: {'beta': 3105062.6339175208, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:01:04,901] Trial 203 finished with value: 0.024469469077512386 and parameters: {'beta': 3412084.226031985, 'span': 15}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:01:50,342] Trial 204 finished with value: 0.022678441283535123 and parameters: {'beta': 3522026.9325011163, 'span': 18}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:02:38,709] Trial 205 finished with value: 0.022678441283535127 and parameters: {'beta': 9316340.961170014, 'span': 18}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:03:28,887] Trial 206 finished with value: 0.023095109021888813 and parameters: {'beta': 9097120.636110809, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:04:20,677] Trial 207 finished with value: 0.023095109021888802 and parameters: {'beta': 9694470.973172333, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:05:13,436] Trial 208 finished with value: 0.02267844128353513 and parameters: {'beta': 7505269.3757113665, 'span': 18}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:05:52,043] Trial 209 finished with value: 0.0230951090218888 and parameters: {'beta': 8025528.3943410255, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:06:38,944] Trial 210 finished with value: 0.02309510902188881 and parameters: {'beta': 9499302.280385938, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:07:27,675] Trial 211 finished with value: 0.023095109021888802 and parameters: {'beta': 9724834.511160761, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:08:10,088] Trial 212 finished with value: 0.02341071978165186 and parameters: {'beta': 8615244.306891887, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:08:55,187] Trial 213 finished with value: 0.0230951090218888 and parameters: {'beta': 9721156.575392675, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:09:42,705] Trial 214 finished with value: 0.02341071978165185 and parameters: {'beta': 8720440.697648562, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:10:21,580] Trial 215 finished with value: 0.023410719781651844 and parameters: {'beta': 9283494.541866595, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:11:00,408] Trial 216 finished with value: 0.0244694690775124 and parameters: {'beta': 9085382.142498631, 'span': 15}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:11:48,995] Trial 217 finished with value: 0.02341071978165185 and parameters: {'beta': 9807946.661191825, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:12:25,352] Trial 218 finished with value: 0.024469469077512386 and parameters: {'beta': 9233879.952914178, 'span': 15}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:13:11,450] Trial 219 finished with value: 0.023095109021888806 and parameters: {'beta': 8009030.410779893, 'span': 17}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:13:52,784] Trial 220 finished with value: 0.02341071978165185 and parameters: {'beta': 9635058.135238077, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:14:38,856] Trial 221 finished with value: 0.023410719781651858 and parameters: {'beta': 9664715.048487175, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:15:24,106] Trial 222 finished with value: 0.023410719781651858 and parameters: {'beta': 9538439.146816, 'span': 16}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:16:14,876] Trial 223 finished with value: 0.0244694690775124 and parameters: {'beta': 9187113.203437882, 'span': 15}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:17:00,205] Trial 224 finished with value: 0.02585801781759094 and parameters: {'beta': 8441972.514820315, 'span': 14}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:17:43,401] Trial 225 finished with value: 0.025858017817590943 and parameters: {'beta': 6971471.087576895, 'span': 14}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:18:20,554] Trial 226 finished with value: 0.025858017817590933 and parameters: {'beta': 9713073.385900509, 'span': 14}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:19:06,409] Trial 227 finished with value: 0.02600447380968818 and parameters: {'beta': 8157338.192175836, 'span': 13}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:19:51,058] Trial 228 finished with value: 0.025858017817590947 and parameters: {'beta': 8730889.066564929, 'span': 14}. Best is trial 196 with value: 0.026004473809688185.
# [I 2023-05-13 21:20:35,735] Trial 229 finished with value: 0.02600447380968819 and parameters: {'beta': 9843168.197403274, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:21:22,079] Trial 230 finished with value: 0.02600447380968818 and parameters: {'beta': 9967075.813580373, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:22:10,447] Trial 231 finished with value: 0.026004473809688174 and parameters: {'beta': 5758672.862504607, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:22:54,450] Trial 232 finished with value: 0.02600447380968818 and parameters: {'beta': 9659428.730045177, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:23:44,900] Trial 233 finished with value: 0.025858017817590943 and parameters: {'beta': 6162377.359700774, 'span': 14}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:24:31,626] Trial 234 finished with value: 0.02600447380968818 and parameters: {'beta': 6288618.4507212015, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:25:14,711] Trial 235 finished with value: 0.026004473809688185 and parameters: {'beta': 5126778.5146567905, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:25:59,604] Trial 236 finished with value: 0.02600447380968819 and parameters: {'beta': 4484090.658788697, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:26:40,840] Trial 237 finished with value: 0.026004473809688185 and parameters: {'beta': 4956788.11430585, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:27:14,891] Trial 238 finished with value: 0.026004473809688185 and parameters: {'beta': 5017845.106968559, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:27:52,257] Trial 239 finished with value: 0.01571584628719598 and parameters: {'beta': 4783329.505372095, 'span': 12}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:28:37,828] Trial 240 finished with value: 0.015715846287195977 and parameters: {'beta': 4767101.317193335, 'span': 12}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:29:30,770] Trial 241 finished with value: 0.01571584628719597 and parameters: {'beta': 4455799.039031883, 'span': 12}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:30:10,768] Trial 242 finished with value: 0.026004473809688185 and parameters: {'beta': 4556564.649093388, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:30:52,685] Trial 243 finished with value: 0.02600447380968818 and parameters: {'beta': 4821395.625981761, 'span': 13}. Best is trial 229 with value: 0.02600447380968819.
# [I 2023-05-13 21:31:27,697] Trial 244 finished with value: 0.0260044738096882 and parameters: {'beta': 4547578.249072986, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:32:04,959] Trial 245 finished with value: 0.026004473809688188 and parameters: {'beta': 4807584.43364128, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:32:45,101] Trial 246 finished with value: 0.006218625632481746 and parameters: {'beta': 4154339.664090611, 'span': 11}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:33:37,904] Trial 247 finished with value: 0.0017027387942683972 and parameters: {'beta': 4698518.840503086, 'span': 10}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:34:26,942] Trial 248 finished with value: 0.026004473809688185 and parameters: {'beta': 4639415.004381229, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:35:12,909] Trial 249 finished with value: 0.02600447380968818 and parameters: {'beta': 4170307.555887535, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:35:52,692] Trial 250 finished with value: 0.0017027387942683968 and parameters: {'beta': 4765892.518947694, 'span': 10}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:36:38,635] Trial 251 finished with value: 0.02600447380968819 and parameters: {'beta': 4740973.64575001, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:37:25,202] Trial 252 finished with value: 0.026004473809688178 and parameters: {'beta': 4779811.489490995, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:38:17,011] Trial 253 finished with value: 0.02600447380968818 and parameters: {'beta': 4750933.658549288, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:39:04,172] Trial 254 finished with value: 0.0 and parameters: {'beta': 3853550.003419872, 'span': 9}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:39:49,780] Trial 255 finished with value: 0.026004473809688188 and parameters: {'beta': 4571296.169591803, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:40:39,158] Trial 256 finished with value: 0.02600447380968818 and parameters: {'beta': 4315832.166391497, 'span': 13}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:41:23,117] Trial 257 finished with value: 0.0 and parameters: {'beta': 3970541.5526105207, 'span': 9}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:42:12,086] Trial 258 finished with value: 0.015715846287195977 and parameters: {'beta': 5071507.217419022, 'span': 12}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:42:57,359] Trial 259 finished with value: 0.01571584628719597 and parameters: {'beta': 2317540.1918564243, 'span': 12}. Best is trial 244 with value: 0.0260044738096882.
# [I 2023-05-13 21:43:33,494] Trial 260 finished with value: 0.0 and parameters: {'beta': 2434610.262176963, 'span': 9}. Best is trial 244 with value: 0.0260044738096882.
# ...
# [I 2023-05-14 12:25:38,534] Trial 1428 finished with value: 0.0017027387942683972 and parameters: {'beta': 0.08614995010679906, 'span': 10}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:26:26,151] Trial 1429 finished with value: 0.0 and parameters: {'beta': 1.9652688979608461, 'span': 8}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:27:02,375] Trial 1430 finished with value: 0.0 and parameters: {'beta': 3.8211624238390176e-07, 'span': 3}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:27:48,664] Trial 1431 finished with value: 0.02243418799583082 and parameters: {'beta': 5538.335642870689, 'span': 18}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:28:38,904] Trial 1432 finished with value: 0.017527016145157826 and parameters: {'beta': 74467.60506959785, 'span': 32}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:29:23,803] Trial 1433 finished with value: 0.01571584628719598 and parameters: {'beta': 1986270.461775428, 'span': 12}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:30:10,973] Trial 1434 finished with value: 0.023682750890197994 and parameters: {'beta': 0.0022649255609918256, 'span': 15}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:30:58,518] Trial 1435 finished with value: 0.006218625632481749 and parameters: {'beta': 3808709.3714618655, 'span': 11}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:31:45,548] Trial 1436 finished with value: 0.022035242435793922 and parameters: {'beta': 9990547.39641112, 'span': 20}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:32:36,564] Trial 1437 finished with value: 0.01857140556307926 and parameters: {'beta': 1108568.260931799, 'span': 2337}. Best is trial 752 with value: 0.026005103820129008.
# [I 2023-05-14 12:33:22,607] Trial 1438 finished with value: 0.026007073613335752 and parameters: {'beta': 29204.473999145113, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:34:12,115] Trial 1439 finished with value: 0.016684702781383436 and parameters: {'beta': 37850.12319652379, 'span': 88}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:34:50,101] Trial 1440 finished with value: 0.016672650925557288 and parameters: {'beta': 19016.672205027684, 'span': 100}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:35:47,826] Trial 1441 finished with value: 0.01907820858630685 and parameters: {'beta': 12354.27577180144, 'span': 1150}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:36:30,639] Trial 1442 finished with value: 0.02584324057936522 and parameters: {'beta': 25191.795038053133, 'span': 14}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:37:22,236] Trial 1443 finished with value: 0.019751930037446006 and parameters: {'beta': 52869.61552886083, 'span': 446}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:38:11,470] Trial 1444 finished with value: 0.01853945526470794 and parameters: {'beta': 69107.9552629913, 'span': 2962}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:38:59,745] Trial 1445 finished with value: 0.023084248308488355 and parameters: {'beta': 34743.17026485847, 'span': 17}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:39:47,307] Trial 1446 finished with value: 0.0 and parameters: {'beta': 218782.94035099162, 'span': 7}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:40:29,753] Trial 1447 finished with value: 0.0 and parameters: {'beta': 119613.86452040136, 'span': 5}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:41:19,314] Trial 1448 finished with value: 0.018007798701103372 and parameters: {'beta': 19882.276915607952, 'span': 152}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:42:07,764] Trial 1449 finished with value: 0.0 and parameters: {'beta': 3109.697790317882, 'span': 9}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:42:55,201] Trial 1450 finished with value: 0.01968333773086868 and parameters: {'beta': 109622.42775714217, 'span': 661}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:43:40,405] Trial 1451 finished with value: 0.026004473809688185 and parameters: {'beta': 383957.43918708194, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:44:29,192] Trial 1452 finished with value: 0.006218625632481747 and parameters: {'beta': 37249.71506949629, 'span': 11}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:45:15,083] Trial 1453 finished with value: 0.02340503329840346 and parameters: {'beta': 69442.92439567854, 'span': 16}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:46:06,833] Trial 1454 finished with value: 0.01601952057997794 and parameters: {'beta': 2.6111886465336733e-06, 'span': 23}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:46:52,267] Trial 1455 finished with value: 0.026003541496939512 and parameters: {'beta': 7601.320247646456, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:47:44,339] Trial 1456 finished with value: 0.0017027387942683966 and parameters: {'beta': 0.02374217929311267, 'span': 10}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:48:33,226] Trial 1457 finished with value: 0.02004815231064551 and parameters: {'beta': 0.0012634735066612383, 'span': 19}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:49:23,620] Trial 1458 finished with value: 0.015519182711069274 and parameters: {'beta': 18.664193988879337, 'span': 12}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:50:05,970] Trial 1459 finished with value: 0.024469469077512386 and parameters: {'beta': 174351.38141378155, 'span': 15}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:50:52,995] Trial 1460 finished with value: 0.0062551303554437025 and parameters: {'beta': 4.05490056865929, 'span': 11}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:51:37,654] Trial 1461 finished with value: 0.0 and parameters: {'beta': 0.0007642011234541655, 'span': 9}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:52:18,644] Trial 1462 finished with value: 0.01939379579493651 and parameters: {'beta': 541846.1391936656, 'span': 25}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:53:00,217] Trial 1463 finished with value: 0.02327574999323659 and parameters: {'beta': 10552.067276508356, 'span': 16}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:53:45,846] Trial 1464 finished with value: 0.0 and parameters: {'beta': 53.211012593011404, 'span': 8}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:54:24,987] Trial 1465 finished with value: 0.026004473809688178 and parameters: {'beta': 348743.99038536445, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:55:09,374] Trial 1466 finished with value: 0.021532903637555716 and parameters: {'beta': 21192.782000834843, 'span': 20}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:55:55,254] Trial 1467 finished with value: 0.0017027387942683966 and parameters: {'beta': 89847.14187653387, 'span': 10}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:56:40,264] Trial 1468 finished with value: 0.0 and parameters: {'beta': 369.3838987981831, 'span': 6}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:57:18,874] Trial 1469 finished with value: 0.0 and parameters: {'beta': 1.2789420211732261e-05, 'span': 1}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:58:06,693] Trial 1470 finished with value: 0.025809392935986736 and parameters: {'beta': 2084.6904331888004, 'span': 14}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:58:46,197] Trial 1471 finished with value: 0.016386603696083236 and parameters: {'beta': 969.5734256986267, 'span': 465}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 12:59:36,820] Trial 1472 finished with value: 0.013244088484984741 and parameters: {'beta': 0.04860845601064132, 'span': 36}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:00:23,453] Trial 1473 finished with value: 0.023095109021888813 and parameters: {'beta': 773481.6558861277, 'span': 17}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:01:10,194] Trial 1474 finished with value: 0.015519298588996002 and parameters: {'beta': 0.2623115754293935, 'span': 12}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:01:59,730] Trial 1475 finished with value: 0.0244694690775124 and parameters: {'beta': 183619.7908877217, 'span': 15}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:02:44,587] Trial 1476 finished with value: 0.0 and parameters: {'beta': 0.06471168907748187, 'span': 8}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:03:25,431] Trial 1477 finished with value: 0.006255130355443701 and parameters: {'beta': 0.0030333931180340206, 'span': 11}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:04:11,559] Trial 1478 finished with value: 0.026004473809688188 and parameters: {'beta': 1414760.5400242812, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:04:58,599] Trial 1479 finished with value: 0.02600447380968818 and parameters: {'beta': 533713.1974513974, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:05:36,289] Trial 1480 finished with value: 0.022033823530398098 and parameters: {'beta': 1139098.630425624, 'span': 20}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:06:20,355] Trial 1481 finished with value: 0.013384528604398812 and parameters: {'beta': 0.716799453451452, 'span': 29}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:07:07,174] Trial 1482 finished with value: 0.019567011883435428 and parameters: {'beta': 53168.28623562234, 'span': 354}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:07:54,429] Trial 1483 finished with value: 0.0017027387942683974 and parameters: {'beta': 0.0004767855564710554, 'span': 10}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:08:42,395] Trial 1484 finished with value: 0.0230951090218888 and parameters: {'beta': 271209.86492236616, 'span': 17}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:09:26,452] Trial 1485 finished with value: 0.025858017817590943 and parameters: {'beta': 1599335.224313701, 'span': 14}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:10:10,666] Trial 1486 finished with value: 0.006218625632481748 and parameters: {'beta': 621662.3298423642, 'span': 11}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:10:57,371] Trial 1487 finished with value: 0.0 and parameters: {'beta': 9251.135254836836, 'span': 9}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:11:36,194] Trial 1488 finished with value: 0.01697812188383384 and parameters: {'beta': 95.23791755445338, 'span': 23}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:12:08,554] Trial 1489 finished with value: 0.0 and parameters: {'beta': 141625.2788420646, 'span': 2}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:12:48,208] Trial 1490 finished with value: 0.012520406528136576 and parameters: {'beta': 2.9115508716080885, 'span': 42}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:13:40,708] Trial 1491 finished with value: 0.011437686043052876 and parameters: {'beta': 4.447825402848216e-05, 'span': 288}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:14:31,221] Trial 1492 finished with value: 0.017761096767131834 and parameters: {'beta': 28725.69798695041, 'span': 127}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:15:12,725] Trial 1493 finished with value: 0.02131015192179898 and parameters: {'beta': 3.7373563510564397e-06, 'span': 17}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:15:56,589] Trial 1494 finished with value: 0.026004473809688188 and parameters: {'beta': 2095720.1925690619, 'span': 13}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:16:40,229] Trial 1495 finished with value: 0.01854354736092406 and parameters: {'beta': 1139656.9808046431, 'span': 2891}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:17:32,909] Trial 1496 finished with value: 0.016189053683671965 and parameters: {'beta': 409479.3358791224, 'span': 65}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:18:18,686] Trial 1497 finished with value: 0.0 and parameters: {'beta': 3233741.8347201077, 'span': 7}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:18:58,333] Trial 1498 finished with value: 0.0 and parameters: {'beta': 251820.52892830383, 'span': 3}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:19:51,810] Trial 1499 finished with value: 0.023682750890197987 and parameters: {'beta': 0.003538416076661504, 'span': 15}. Best is trial 1438 with value: 0.026007073613335752.
# [I 2023-05-14 13:20:40,109] Trial 1500 finished with value: 0.006230398828956876 and parameters: {'beta': 171.99282419009066, 'span': 11}. Best is trial 1438 with value: 0.026007073613335752.
# ERROR:root:KeyboardInterrupt while sending command.============>(127 + 1) / 128] 1) / 128]]]
# Traceback (most recent call last):
#   File "/ext3/pyspark/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/ext3/pyspark/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/ext3/pyspark/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# [W 2023-05-14 13:20:56,579] Trial 1501 failed with parameters: {'beta': 3.178562048979932e-07, 'span': 176} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/jes9857/.local/lib/python3.10/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/state/partition1/job-33309509/ipykernel_1523285/3881882750.py", line 14, in objective
#     map_val = calc_performance_metrics(baseline_pops_train, utility_mat_val)
#   File "/state/partition1/job-33309509/ipykernel_1523285/1659754758.py", line 133, in calc_performance_metrics
#     ).evaluate(results)
#   File "/ext3/pyspark/lib/python3.10/site-packages/pyspark/ml/evaluation.py", line 111, in evaluate
#     return self._evaluate(dataset)
#   File "/ext3/pyspark/lib/python3.10/site-packages/pyspark/ml/evaluation.py", line 148, in _evaluate
#     return self._java_obj.evaluate(dataset._jdf)
#   File "/ext3/pyspark/lib/python3.10/site-packages/py4j/java_gateway.py", line 1320, in __call__
#     answer = self.gateway_client.send_command(command)
#   File "/ext3/pyspark/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/ext3/pyspark/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/ext3/pyspark/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# [W 2023-05-14 13:20:56,580] Trial 1501 failed with value None.
#
# KeyboardInterrupt

# %%
study.best_params
# Out:
# {'beta': 29204.473999145113, 'span': 13}

# %%
utility_mat_train = gen_utiltiy_matrix(interactions_train, tracks_train, span=study.best_params['span'])
utility_mat_val = gen_utiltiy_matrix(interactions_val, tracks_train, span=study.best_params['span'])
utility_mat_test = gen_utiltiy_matrix(interactions_test, tracks_test, span=study.best_params['span'])

baseline_pops_train = calc_baseline_popularity(utility_mat_train, study.best_params['beta'])
    
metrics_train = calc_performance_metrics(baseline_pops_train, utility_mat_train)
metrics_val = calc_performance_metrics(baseline_pops_train, utility_mat_val)
metrics_test = calc_performance_metrics(baseline_pops_train, utility_mat_test)
# Out:
#                                                                                 + 16) / 200]

# %%
metrics_train, metrics_val, metrics_test
# Out:
# (0.06759150726394776, 0.02600707361333576, 0.0212393273145651)
